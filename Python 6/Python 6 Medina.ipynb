# %%
import pandas as pd
df = pd.read_csv('data_sf.csv')

# %%
df
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
#            Value    Wage Position  Crossing  Finishing  ...  Penalties  \
# 0      110500000  565000       RF        84         95  ...         75
# 1       77000000  405000       ST        84         94  ...         85
# 2      118500000  290000       LW        79         87  ...         81
# 3       72000000  260000       GK        17         13  ...         40
# 4      102000000  355000      RCM        93         82  ...         79
# ...          ...     ...      ...       ...        ...  ...        ...
# 12892    1100000    1000       CM        34         38  ...         43
# 12893      60000    1000       ST        23         52  ...         43
# 12894      60000    1000       ST        25         40  ...         55
# 12895      60000    1000       RW        44         50  ...         50
# 12896      60000    1000       CM        41         34  ...         33
#
#        Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0             96       33              28             26         6
# 1             95       28              31             23         7
# 2             94       27              24             33         9
# 3             68       15              21             13        90
# 4             88       68              58             51        15
# ...          ...      ...             ...            ...       ...
# 12892         45       40              48             47        10
# 12893         42       22              15             19        10
# 12894         41       32              13             11         6
# 12895         46       20              25             27        14
# 12896         43       40              43             50        10
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes
# 0              11         15             14           8
# 1              11         15             14          11
# 2               9         15             15          11
# 3              85         87             88          94
# 4              13          5             10          13
# ...           ...        ...            ...         ...
# 12892          13          7              8           9
# 12893           9          9              5          12
# 12894           5         10              6          13
# 12895           6         14              8           9
# 12896          15          9             12           9
#
# [12897 rows x 42 columns]

# %%
small_df = df[df.columns[1:8]].head(25)
small_df
s = df['Club'].value_counts()
display(s)
# Out:
# V-Varen Nagasaki     30
# Shonan Bellmare      30
# De Graafschap        29
# Padova               29
# Vissel Kobe          29
#                      ..
# Dijon FCO             8
# Dinamo Zagreb         7
# Vitória Guimarães     7
# GD Chaves             7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %%
s.index[1]
# Out:
# 'Shonan Bellmare'

# %%
len(s.index)
# Out:
# 650

# %%
s = df['Position'].value_counts(normalize=True)
display(s)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# LAM    0.000465
# RF     0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
s = df['FKAccuracy'].value_counts(bins=4)
display(s)
# Out:
# (25.75, 48.5]     6725
# (48.5, 71.25]     3388
# (2.908, 25.75]    2328
# (71.25, 94.0]      456
# Name: FKAccuracy, dtype: int64

# %%
result = len(df['Position'].value_counts())

# %%
result
# Out:
# 12897

# %%
Spain_players = df[df.Nationality =='Spain']
s = Spain_players['Wage'].value_counts(bins=4)
display(s)
# Out:
# (620.999, 95750.0]      651
# (95750.0, 190500.0]      11
# (190500.0, 285250.0]      6
# (285250.0, 380000.0]      3
# Name: Wage, dtype: int64

# %%
Spain_players['Wage'].nunique()
# Out:
# 77

# %%
MU_players = df[df.Club =='Manchester United']

# %%
MU_players['Nationality'].nunique()
# Out:
# 13

# %%
s = MU_players['Nationality'].value_counts()
s_df = s.reset_index()

display(s_df)
# Out:
#           index  Nationality
# 0       England            6
# 1     Argentina            2
# 2        France            2
# 3        Serbia            1
# 4         Italy            1
# 5      Scotland            1
# 6       Belgium            1
# 7         Spain            1
# 8       Ecuador            1
# 9        Brazil            1
# 10        Chile            1
# 11        Wales            1
# 12  Ivory Coast            1

# %%
s_df.columns = ['Nationality','Players Count']

display(s_df)
# Out:
#     Nationality  Players Count
# 0       England              6
# 1     Argentina              2
# 2        France              2
# 3        Serbia              1
# 4         Italy              1
# 5      Scotland              1
# 6       Belgium              1
# 7         Spain              1
# 8       Ecuador              1
# 9        Brazil              1
# 10        Chile              1
# 11        Wales              1
# 12  Ivory Coast              1

# %%
Brazil_players = df[df.Nationality =='Brazil']
JV_players = df[df.Club =='Juventus']
JV_players
# Out:
#       Unnamed: 0               Name  Age         Nationality      Club  \
# 1              1  Cristiano Ronaldo   33            Portugal  Juventus
# 15            15          P. Dybala   24           Argentina  Juventus
# 24            24       G. Chiellini   33               Italy  Juventus
# 64            64        Alex Sandro   27              Brazil  Juventus
# 65            65      Douglas Costa   27              Brazil  Juventus
# 70            70         L. Bonucci   31               Italy  Juventus
# 72            72          M. Pjanić   28  Bosnia Herzegovina  Juventus
# 73            73         M. Benatia   31             Morocco  Juventus
# 92            92        W. Szczęsny   28              Poland  Juventus
# 99            99         S. Khedira   31             Germany  Juventus
# 103          103         B. Matuidi   31              France  Juventus
# 131          131       M. Mandžukić   32             Croatia  Juventus
# 612          620      L. Spinazzola   25               Italy  Juventus
# 8644        8837        P. Beruatto   19               Italy  Juventus
#
#          Value    Wage Position  Crossing  Finishing  ...  Penalties  \
# 1     77000000  405000       ST        84         94  ...         85
# 15    89000000  205000       LF        82         84  ...         86
# 24    27000000  215000      LCB        58         33  ...         50
# 64    36500000  160000       LB        84         55  ...         60
# 65    46500000  175000       LM        84         67  ...         77
# 70    30000000  160000      RCB        44         48  ...         70
# 72    44000000  180000      CDM        80         60  ...         79
# 73    30000000  160000       CB        45         47  ...         41
# 92    32000000  125000       GK        12         12  ...         18
# 99    33000000  160000      RCM        72         72  ...         69
# 103   26000000  145000       LM        75         64  ...         56
# 131   25000000  160000       ST        72         84  ...         76
# 612   11000000   80000       LM        76         60  ...         59
# 8644    575000    5000       LB        50         10  ...         43
#
#       Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 1            95       28              31             23         7          11
# 15           84       23              20             20         5           4
# 24           84       93              93             90         3           3
# 64           82       81              84             84         7           7
# 65           84       45              38             34        13          15
# 70           86       90              86             80         2           2
# 72           86       75              74             70         7           7
# 73           82       89              87             85         7           4
# 92           65       20              13             12        85          81
# 99           84       80              83             76        11           9
# 103          82       85              84             86         8          11
# 131          80       59              64             64        10           8
# 612          74       77              76             76        11          13
# 8644         56       64              66             68        14           5
#
#       GKKicking  GKPositioning  GKReflexes
# 1            15             14          11
# 15            4              5           8
# 24            2              4           3
# 64            9             12           5
# 65            9             12           5
# 70            3              2           4
# 72           13              7           8
# 73            8              7          11
# 92           71             85          87
# 99            5             15           8
# 103           5             10          14
# 131           5              8          15
# 612          12             15          14
# 8644         12             10          12
#
# [14 rows x 42 columns]

# %%
s = JV_players['Name'].value_counts()
s_df = s.reset_index()

# %%
s_df.columns = ['Name','Players Count']
display(s_df.sort_values(by=['Name']))
# Out:
#                  Name  Players Count
# 4         Alex Sandro              1
# 8          B. Matuidi              1
# 2   Cristiano Ronaldo              1
# 1       Douglas Costa              1
# 5        G. Chiellini              1
# 13         L. Bonucci              1
# 12      L. Spinazzola              1
# 3          M. Benatia              1
# 10       M. Mandžukić              1
# 9           M. Pjanić              1
# 11        P. Beruatto              1
# 0           P. Dybala              1
# 6          S. Khedira              1
# 7         W. Szczęsny              1

# %%
sorted_names = s_df['Name'].unique()

# %%
display(sorted_names.sort_values(by=['Name']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-9ec7663a794d> in <module>
# ----> 1 display(sorted_names.sort_values(by=['Name']))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sort_values'

# %%
s = df['Age'].value_counts()
display(s)
# Out:
# 21    1060
# 20     989
# 22     972
# 19     907
# 24     902
# 23     900
# 25     854
# 26     850
# 27     759
# 28     720
# 18     665
# 29     656
# 30     549
# 31     441
# 32     379
# 34     281
# 33     271
# 17     269
# 35     158
# 36     123
# 37      70
# 16      42
# 38      35
# 39      24
# 40      13
# 41       4
# 44       2
# 45       1
# 42       1
# Name: Age, dtype: int64

# %%
df.loc[(df['Age'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]

# %%
small_df = df[df.columns[0:7]].head(25)

# %%
s = small_df['Wage'].value_counts(bins=4)

# %%
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
s.index
# Out:
# Int64Index([21, 20, 22, 19, 24, 23, 25, 26, 27, 28, 18, 29, 30, 31, 32, 34, 33,
#             17, 35, 36, 37, 16, 38, 39, 40, 41, 44, 45, 42],
#            dtype='int64')

# %%
s.index[18]
# Out:
# 35

# %%
OldAge = df.loc[df['Age'] >= s.index[18]]

# %%
OldAge['Club'].value_counts()
# Out:
# Hokkaido Consadole Sapporo             4
# Chongqing Dangdai Lifan FC SWM Team    4
# San Martín de San Juan                 4
# Club Atlético Huracán                  4
# Júbilo Iwata                           4
#                                       ..
# FC Groningen                           1
# NAC Breda                              1
# Villarreal CF                          1
# Zagłębie Lubin                         1
# Hamilton Academical FC                 1
# Name: Club, Length: 296, dtype: int64

# %%
ARG_players = df[df.Nationality =='Argentina']

# %%
ARG_players['Age'].value_counts(bins = 4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
Spain_players = df[df.Nationality =='Spain']

# %%
Spain_players['Age'].value_counts()
# Out:
# 21    79
# 22    64
# 20    52
# 23    48
# 25    43
# 27    42
# 24    40
# 28    36
# 26    36
# 19    32
# 29    32
# 18    26
# 30    26
# 31    22
# 32    22
# 33    21
# 34    15
# 17     9
# 35     8
# 36     7
# 37     6
# 16     2
# 39     2
# 38     1
# Name: Age, dtype: int64
