# %% [markdown]
# # 1.1. О чём этот модуль

# %%
#Задание 1.1.1
#Что такое машинное обучение?
answer1 = "Процесс, в ходе которого алгоритм принимает на вход данные и учится находить в них закономерности"

# %%
#Задание 1.1.2
#Выберите, какие этапы включает в себя решение задач машинного обучения:
answer2 = '''
- Определение требований;
- Предобработка;
- Моделирование;
- Тестирование;
- Внедрение.'''

# %%
#Задание 1.1.3
#В каком порядке включают друг друга разные области анализа данных?
answer3 = "Искусственный интеллект включает в себя машинное обучение, машинное обучение — глубокое обучение"
# Out:
# '\n- Определение требований;\n- Предобработка;\n- Моделирование;\n- Тестирование;\n- Внедрение.'

# %% [markdown]
# # 1.2. Типы алгоритмов

# %%
#Задание 1.2.1
#К какому классу и подклассу алгоритмов МО относится эта задача: «Предскажите время в секундах, через которое ваше оборудование сломается. Вам известны — тип оборудования, его производитель, дата производства и еще несколько признаков»?
answer4 = "Класс обучение с учителем, подкласс регрессия"

# %%
#Задание 1.2.2
#Кроме типа оборудования, производителя и даты производства, у вас есть ещё тысяча признаков, что слишком много для анализа. Каким классом алгоритмов вы воспользуетесь, чтобы признаков стало меньше?
answer5 = "Обучение без учителя"

# %%
#Задание 1.2.3
#Выберите, как соотносятся между собой обучение с учителем и обучение с подкреплением:
answer6 = "Эти классы похожи, но являются независимыми"

# %%
#Задание 1.2.4
#Задача — разбить пользователей интернет-магазина на группы, зная только информацию об их покупках. Определите тип задачи МО?
answer7 = "Кластеризация"

# %% [markdown]
# # 1.3. Задачи машинного обучения

# %%
#Задание 1.3.1
#Укажите, какой тип алгоритмов МО решает задачу определения спама в письмах:
ans8 = "Классификация"

# %%
#Задание 1.3.2
#В каких задачах применяются алгоритмы компьютерного зрения?
ans9 = "Классификация болезней по фото"

# %%
#Задание 1.3.3
#У вас есть беспилотный автомобиль, который смотрит на дорогу, определяет людей, разметку и дорожные знаки перед ним, считает расстояние до каждого человека и машин вокруг. Выберите, какие задачи машинного обучения решает этот автомобиль:
ans10 = "Распознавание фото/видео"

# %%
#Задание 1.3.4
#Вы собираетесь в августе в поход к островам, для этого вам нужна лодка в прокат. В мае лодочная станция предлагала лодку за 1400 руб. на выходные и 1100 руб. на два будних дня, в августе — за 1800 руб. на выходные и 1600 руб. на два будних дня. Определите тип задачи МО, впишите полное название:
ans11 = "МО с учителем Регрессия"

# %% [markdown]
# # 1.4. Частые вопросы

# %%
### Задание 1.4.1
#Что такое слабый (узкий, частный) искусственный интеллект?
ans12 = "Специальный алгоритм, который можно обучить для решения конкретной узкой задачи"

# %%
#Задание 1.4.2
#Выберите правдивое утверждение:
ans13 = "Машинное обучение — это практическое применение статистики"

# %%
### Задание 1.4.3
#Существует ли сильный (широкий, общий) искусственный интеллект?
ans14 = "Нет"

# %% [markdown]
# # 1.5. Методология разработки задач

# %%
### Задание 1.5.1
#Почему каскадная методология разработки редко применяется в Data Science разработке?
ans15 = "Каскадная модель слишком неповоротлива: она предполагает возможность заранее полностью определить, как мы можем решать задачу"

# %%
### Задание 1.5.2
#Что такое Insight Mining (поиск инсайтов)?
ans16 = "Все перечисленное"

# %%
### Задание 1.5.3
#Выберите, на каких стадиях разработки мы занимаемся поиском инсайтов:
ans17 = "Предобработка"

# %%
#Задание 1.5.4
#Как заранее определить, подтвердится гипотеза или нет?
ans18 = "Заранее определить нельзя, можно лишь иметь некоторую степень уверенности"

# %% [markdown]
# # 1.6. Определение бизнес-требований

# %%
### Задание 1.6.1
#Как расшифровывается MVP?
ans19 = "Minimum Viable Product"

# %%
### Задание 1.6.2
#Укажите, какой должна быть SMART-цель:
ans21 = - '''[ ]  Конкретная
- [ ]  Измеримая
- [ ]  Достижимая
- [ ]  Значимая (релевантная)
- [ ]  Ограниченная по времени
'''

# %%
### Задание 1.6.3
#Вы работаете на заводе. Перед вами два тезиса: ускорить проход сотрудников на работу и с работы и поставить систему биометрии по видео на вход. Выберите верные утверждения:
ans22 = "И то, и другое — цель; Ускорить проход сотрудников — цель (но пока не SMART);Поставить систему биометрии — цель (но пока не SMART)"

# %%
### Задание 1.6.4
#Задача — классифицировать документы некой компании, о которой вы ничего не знаете. Как будете действовать на этапе определения требований?
ans23 = "Узнаю, чем занимается компания;Узнаю, на какие классы нужно классифицировать документы;Узнаю, есть ли в данных структура"

# %% [markdown]
# # 1.7. Сбор и подготовка данных

# %%
### Задание 1.7.1
#Что означает принцип «Garbage in — garbage out»?
ans24 = "Если подать алгоритму плохие данные, он не научится выдавать хороший результат"

# %%
### Задание 1.7.2
#Что такое обогащение данных?
ans25 = "Добавление новых данных извне"

# %%
### Задание 1.7.3
#Что такое логирование действий?
ans26 = "Регистрация, протоколирование действий, часто в хронологической последовательности"

# %%
### Задание 1.7.4
#Вам нужно создать алгоритм для распознавания возраста по фотографии. 
#Заказчик дал фотографии людей от 18 до 30 лет, утверждая, что это 
#основной возраст клиентов. Что будете делать?
ans27 = "Запрошу данные для других возрастов, чтобы дать более полную информацию модели"

# %% [markdown]
# # 1.8. Разработка модели

# %%
### Задание 1.8.1
#Выберите, какие шаги нужно предпринять для обучения модели:
ans29 = "Выбрать гиперпараметры модели;Выбрать алгоритм оптимизации;Подать данные в алгоритм и дождаться обучения"

# %%
### Задание 1.8.2
#В каком порядке мы повторяем этапы цикла обучения модели?
ans29 = "Делаем разведывательный анализ данных, выбираем гиперпараметры модели, обучаем и валидируем модель"

# %%
### Задание 1.8.3
#Укажите, может ли алгоритм машинного обучения идеально точно делать прогнозы в реальной задаче:
ans30 = "В большинстве случаев нет, так как в реальном мире все задачи неточные и везде есть влияние случайности, которую модель не сможет спрогнозировать"

# %%
### Задание 1.8.4
#Выберите верные утверждения:
ans31 = "Для обучения нейронных сетей желательно иметь видеокарту;Для обучения классических алгоритмов МО достаточно процессора"

# %% [markdown]
# # 1.9. Тестирование и внедрение модели

# %%
### Задание 1.9.1
#Зачем нужно unit-тестирование?
ans32 = "Для тестирования одной единицы функциональности в программе, например, загрузки данных"

# %%
### Задание 1.9.2
#Зачем нужно нагрузочное тестирование?
ans33 = "Для определения того, какую часть Pipeline оптимизировать"

# %%
### Задание 1.9.3
#Зачем валидировать модель?
ans34 = "Чтобы определить, насколько хорошо идёт процесс обучения"

# %%
### Задание 1.9.4
#Что является примером интеграционного тестирования?
ans35 = "Тестирование работы каждого этапа Pipeline совместно"

# %%
### Задание 1.9.5
#У заказчика на сайте настроена платная подписка. Схема работы должна быть следующей: сервис обрабатывает данные и создаёт подписку, присылает информацию по оплате, обрабатывает заказ, предоставляет подписчику услугу. Определите, какой вид тестирования следует использовать для проверки работы схемы:
ans36 = "Нагрузочные тесты"

# %% [markdown]
# # 1.10. Проблемы разработки моделей

# %%
### Задание 1.10.1
#Можно ли с первого раза сделать рабочую модель?
ans37 = "Нет"

# %%
### Задание 1.10.2
#Какой этап Data Science разработки самый большой?
ans38 = "Предобработка"

# %%
### Задание 1.10.3
#Из-за чего может оказаться так, что вы недооценили время, которое потратите на предобработку?
ans39 = "Не учли всех бизнес-требований;У вас/ваших разработчиков оказалось недостаточно опыта для определения возможных проблем при предобработке"

# %% [markdown]
# # 1.11. Советы и лайфхаки

# %%
### Задание 1.11.1
#акие действия и в каком порядке лучше предпринять, чтобы решить задачу, если сроки ограничены и высокая точность не требуется?
ans40 = "Поискать примеры схожих решенных задач, разработать минимальное рабочее решение, проверить его работоспособность"

# %%
### Задание 1.11.2
#Как лучше проверять гипотезы в разработке Data Science?
ans41 = "Придумать интересную гипотезу, проверить её разными способами и средствами. Если гипотеза сработает — продолжить проверку, если нет — потратить время на модификацию гипотезы и вернуться в начало"

# %%
### Задание 1.11.3
#Выберите вредные советы по машинному обучению:
ans42 = "делайте всё как можно быстрее, меньше времени на подбор гипотез;делайте уникальные решения, не берите то, что уже есть"

# %% [markdown]
# # 1.12. Процесс моделирования

# %%
### Задание 1.12.
#Какой из алгоритмов показал лучший результат на данных без дополнительной предобработки?
ans43 = "Градиентный бустинг"

# %%
### Задание 1.12.2
#С помощью какой метрики мы валидировали модель?
ans44 = "Средняя абсолютная ошибка"

# %%
### Задание 1.12.3
#Укажите число признаков в рассматриваемых данных, где есть пропуски:
ans45 = "0"

# %%
### Задание 1.12.4
#Укажите число признаков в рассматриваемых данных, где есть высокая корреляция:
ans46 = "3"

# %%
### Задание 1.12.5
#Какой способ внедрения мы использовали в этом примере?
ans47 = "Мы не занимались внедрением в этом примере"
